# %% [markdown]
# # Data Manipulation
#
# I want to get comfortable with loading and manipulating data in Python. While most of the practice projects will come with structured data which we can load into a `DataFrame` using `pandas`, this one focuses on semi-structured data and how we can "flatten" it and then load it into other formats. The objective is to see how data flows in Python from one object to another and what advantages and disadvantages each offers.
#
# Let's read the `books.json` data set and display the first item in it.

# %%
import json
with open('books.json', encoding = 'utf-8') as f:
    books_dict = json.load(f) #load the json file

from pprint import pprint
pprint(books_dict[0]) # print information for the first book
number_of_books = len(books_dict)
# Out:
# {'_id': 1,
#  'authors': ['W. Frank Ableson', 'Charlie Collins', 'Robi Sen'],
#  'categories': ['Open Source', 'Mobile'],
#  'isbn': '1933988673',
#  'longDescription': 'Android is an open source mobile phone platform based on '
#                     'the Linux operating system and developed by the Open '
#                     'Handset Alliance, a consortium of over 30 hardware, '
#                     'software and telecom companies that focus on open '
#                     'standards for mobile devices. Led by search giant, '
#                     'Google, Android is designed to deliver a better and more '
#                     'open and cost effective mobile experience.    Unlocking '
#                     "Android: A Developer's Guide provides concise, hands-on "
#                     'instruction for the Android operating system and '
#                     'development tools. This book teaches important '
#                     'architectural concepts in a straightforward writing style '
#                     'and builds on this with practical and useful examples '
#                     'throughout. Based on his mobile development experience '
#                     'and his deep knowledge of the arcane Android technical '
#                     'documentation, the author conveys the know-how you need '
#                     'to develop practical applications that build upon or '
#                     'replace any of Androids features, however small.    '
#                     "Unlocking Android: A Developer's Guide prepares the "
#                     'reader to embrace the platform in easy-to-understand '
#                     'language and builds on this foundation with re-usable '
#                     'Java code examples. It is ideal for corporate and '
#                     'hobbyists alike who have an interest, or a mandate, to '
#                     "deliver software functionality for cell phones.    WHAT'S "
#                     "INSIDE:        * Android's place in the market      * "
#                     'Using the Eclipse environment for Android '
#                     'development      * The Intents - how and why they are '
#                     'used      * Application classes:            o '
#                     'Activity            o Service            o '
#                     'IntentReceiver       * User interface design      * Using '
#                     'the ContentProvider to manage data      * Persisting data '
#                     'with the SQLite database      * Networking examples      '
#                     '* Telephony applications      * Notification methods      '
#                     '* OpenGL, animation & multimedia      * Sample '
#                     'Applications  ',
#  'pageCount': 416,
#  'publishedDate': {'$date': '2009-04-01T00:00:00.000-0700'},
#  'shortDescription': "Unlocking Android: A Developer's Guide provides concise, "
#                      'hands-on instruction for the Android operating system '
#                      'and development tools. This book teaches important '
#                      'architectural concepts in a straightforward writing '
#                      'style and builds on this with practical and useful '
#                      'examples throughout.',
#  'status': 'PUBLISH',
#  'thumbnailUrl': 'https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ.book-thumb-images/ableson.jpg',
#  'title': 'Unlocking Android'}

# %% [markdown]
# 1. The following program will through the entire data and extracts the following information:
#
#   - title of the book
#   - name of the first author
#   - name of the second author (if book has more than one author)
#   - number of authors
#   - ISBN
#   - if the word "data" is in the book's description
#   - the number of words in the book's description
#   - the year the book was published
#
#   Of course because JSON data doesn't necessarily enforce any sort of schema, we can't be sure that the information we are trying to extract exists for every book. For example, if the book only has one author, then there is no second author. So use `try` and `except` as we loop through every book and skip to the next item every time some information is missing.
#
#   Store the extracted data in a list named `rows` whose elements are tuples, one tuple per book. For example, the first element of `rows` stores the tuple for the first book and should look like this:
#
#         ('Unlocking Android', 'W. Frank Ableson', 'Charlie Collins', 3, '1933988673', True, 252, 2009)

# %%
# This function is to extract information from a python dictionary and return the followiing information: title,
# first author, second author, number of authors,ISBN, if the description contains the word "data", description word count, and published year
# JSON data doesn't necessarily enforce any sort of schema, I use try and except as I loop through every book

import datetime
def extract_info(some_dict):
    try:
        title = some_dict['title']
    except:
        title = None
    try:
        first_author = some_dict['authors'][0] 
    except:
        first_author = None
    try:
        number_of_authors = len(some_dict['authors'])
    except:
        number_of_authors = 0
    try:
        second_author = some_dict['authors'][1]
    except:
        second_author = None
    try:
        ISBN = some_dict['isbn']      
    except:
        ISBN = None
    try:
        description_word_count = len(some_dict['longDescription'].split())
        if 'data' in some_dict['longDescription'].split():
            has_data = "True"
        else: 
            has_data = "False"
    except:
        description_word_count = 0
        has_data = "False"
    try:     
        published_year = datetime.datetime.strptime(some_dict['publishedDate']['$date'], '%Y-%m-%dT%H:%M:%S.%f%z').year
    except:
        published_year = None
    return (title,first_author, second_author, number_of_authors,ISBN, has_data, description_word_count,published_year)
    
all_books_info=[0 for i in range(len(books_dict))] # create an array to store info
for i in range(len(books_dict)):
    all_books_info[i] = extract_info(books_dict[i]) # call extract info function and store into each element
    print(all_books_info[i]) #print for result visibility
# Out:
# ('Unlocking Android', 'W. Frank Ableson', 'Charlie Collins', 3, '1933988673', 'True', 252, 2009)
# ('Android in Action, Second Edition', 'W. Frank Ableson', 'Robi Sen', 2, '1935182722', 'False', 101, 2011)
# ('Specification by Example', 'Gojko Adzic', None, 1, '1617290084', 'False', 0, 2011)
# ('Flex 3 in Action', 'Tariq Ahmed with Jon Hirschi', 'Faisal Abid', 2, '1933988746', 'True', 254, 2009)
# ('Flex 4 in Action', 'Tariq Ahmed', 'Dan Orlando', 4, '1935182420', 'True', 329, 2010)
# ('Collective Intelligence in Action', 'Satnam Alag', None, 1, '1933988312', 'True', 244, 2008)
# ('Zend Framework in Action', 'Rob Allen', 'Nick Lo', 3, '1933988320', 'False', 291, 2008)
# ('Flex on Java', 'Bernerd Allmon', 'Jeremy Anderson', 2, '1933988797', 'False', 273, 2010)
# ('Griffon in Action', 'Andres Almiray', 'Danno Ferrin', 4, '1935182234', 'False', 240, 2012)
# ('OSGi in Depth', 'Alexandre de Castro Alves', None, 1, '193518217X', 'False', 269, 2011)
# ('Flexible Rails', 'Peter Armstrong', None, 1, '1933988509', 'False', 374, 2008)
# ('Hello! Flex 4', 'Peter Armstrong', None, 1, '1933988762', 'True', 184, 2009)
# ('Coffeehouse', 'Levi Asher', 'Christian Crumlish', 2, '1884777384', 'False', 101, 1997)
# ('Team Foundation Server 2008 in Action', 'Jamil Azher', None, 1, '1933988592', 'False', 293, 2008)
# ('Brownfield Application Development in .NET', 'Kyle Baley', 'Donald Belcham', 2, '1933988711', 'False', 267, 2010)
# ('MongoDB in Action', 'Kyle Banker', None, 1, '1935182870', 'True', 291, 2011)
# ('Distributed Application Development with PowerBuilder 6.0', 'Michael J. Barlotta', None, 1, '1884777686', 'False', 219, 1998)
# ('Jaguar Development with PowerBuilder 7', 'Michael Barlotta', None, 1, '1884777864', 'False', 141, 1999)
# ('Taming Jaguar', 'Michael J. Barlotta', 'Jason R. Weiss', 2, '1884777686', 'True', 179, 2000)
# ('3D User Interfaces with Java 3D', 'Jon Barrilleaux', None, 1, '1884777902', 'True', 192, 2000)
# ('Hibernate in Action', 'Christian Bauer', 'Gavin King', 2, '193239415X', 'False', 191, 2004)
# ('Hibernate in Action (Chinese Edition)', 'Christian Bauer', 'Gavin King', 2, None, 'False', 0, 1999)
# ('Java Persistence with Hibernate', 'Christian Bauer', 'Gavin King', 2, '1932394885', 'True', 153, 2006)
# ('JSTL in Action', 'Shawn Bayern', None, 1, '1930110529', 'False', 140, 2002)
# ('iBATIS in Action', 'Clinton Begin', 'Brandon Goodin', 3, '1932394826', 'True', 159, 2007)
# ('Designing Hard Software', 'Douglas W. Bennett', None, 1, '133046192', 'False', 154, 1997)
# ('Hibernate Search in Action', 'Emmanuel Bernard', 'John Griffin', 2, '1933988649', 'False', 211, 2008)
# ('jQuery in Action', 'Bear Bibeault', 'Yehuda Katz', 2, '1933988355', 'False', 135, 2008)
# ('jQuery in Action, Second Edition', 'Bear Bibeault', 'Yehuda Katz', 2, '1935182323', 'False', 168, 2010)
# ('Building Secure and Reliable Network Applications', 'Kenneth P. Birman', None, 1, '1884777295', 'False', 138, 1996)
# ('Ruby for Rails', 'David A. Black', None, 1, '1932394699', 'True', 119, 2006)
# ('The Well-Grounded Rubyist', 'David A. Black', None, 1, '1933988657', 'False', 236, 2009)
# ("Website Owner's Manual", 'Paul A. Boag', None, 1, '1933988452', 'False', 147, 2009)
# ('ASP.NET 4.0 in Practice', 'Daniele Bochicchio', 'Stefano Mostarda', 4, '1935182463', 'False', 118, 2011)
# ('Hello! Python', 'Anthony Briggs', None, 1, '1935182080', 'False', 217, 2012)
# ("PFC Programmer's Reference Manual", 'Richard Brooks', None, 1, '1884777554', 'False', 171, 1998)
# ('Graphics File Formats', 'C. Wayne Brown', 'Barry J. Shepherd', 2, '133034054', 'True', 144, 1995)
# ('Visual Object Oriented Programming', 'Margaret M. Burnett', 'Adele Goldberg', 4, '131723979', 'False', 127, 1995)
# ('iOS in Practice', 'Bear P. Cahill', None, 1, '1617291269', 'False', 0, 2013)
# ('iPhone in Action', 'Christopher Allen', 'Shannon Appelcline', 2, '193398886X', 'False', 163, 2008)
# ('Silverlight 2 in Action', 'Chad A. Campbell', 'John Stockton', 2, '1933988428', 'False', 296, 2008)
# ('The Quick Python Book, Second Edition', 'Naomi R. Ceder', None, 1, '193518220X', 'True', 138, 2010)
# ('Internet and Intranet Applications with PowerBuilder 6', 'Tom Cervenka', None, 1, '1884777600', 'False', 64, 2000)
# ('Practical Methods for Your Year 2000 Problem', 'Robert Chapman', None, 1, '188477752X', 'False', 211, 1998)
# ('Mobile Agents', 'William R. Cockayne and Michael Zyda', 'editors', 2, '1884777368', 'False', 83, 1997)
# ('Spring Dynamic Modules in Action', 'Arnaud Cogoluegnes', 'Thierry Templier', 4, '1935182307', 'True', 183, 2010)
# ('SQL Server 2008 Administration in Action', 'Rod Colledge', None, 1, '193398872X', 'False', 242, 2009)
# ('Android in Practice', 'Charlie Collins', 'Michael D. Galpin', 4, '1935182927', 'False', 196, 2011)
# ('Object Oriented Perl', 'Damian Conway', None, 1, '1884777791', 'False', 184, 1999)
# ('GWT in Practice', 'Robert Cooper', 'Charles Collins', 2, '1933988290', 'False', 256, 2008)
# ('Ajax in Action', 'Dave Crane', 'Eric Pascarello with Darren James', 2, '1932394613', 'False', 189, 2005)
# ('Ajax in Practice', 'Dave Crane', 'Jord Sonneveld and Bear Bibeault with Ted Goddard', 5, '1932394990', 'False', 179, 2007)
# ('Prototype and Scriptaculous in Action', 'Dave Crane', 'Bear Bibeault with Tom Locke', 2, '1933988037', 'False', 151, 2007)
# ('POJOs in Action', 'Chris Richardson', None, 1, '1932394583', 'False', 146, 2006)
# ('Data Munging with Perl', 'David Cross', None, 1, '1930110006', 'True', 228, 2001)
# ('Hello! HTML5 & CSS3', 'Rob Crowther', None, 1, '1935182897', 'False', 284, 2012)
# ('Seam in Action', 'Dan Allen', None, 1, '1933988401', 'False', 354, 2008)
# ('Wicket in Action', 'Martijn Dashorst', 'Eelco Hillenius', 2, '1932394982', 'False', 132, 2008)
# ('Open Source SOA', 'Jeff Davis', None, 1, '1933988541', 'False', 144, 2009)
# ('Struts 2 in Action', 'Donald Brown', 'Chad Michael Davis', 4, '193398807X', 'False', 245, 2008)
# ('Essential Guide to Peoplesoft Development and Customization', 'Tony DeLia', 'Galina Landres', 4, '1884777929', 'False', 363, 2000)
# ('.NET Multithreading', 'Alan Dennis', None, 1, '1930110545', 'False', 149, 2002)
# ('SCWCD Exam Study Kit Second Edition', 'Hanumant Deshmukh', 'Jignesh Malavia', 4, '1932394389', 'False', 181, 2005)
# ('Spring Roo in Action', 'Ken Rimple', 'Srini Penchikala', 2, '193518296X', 'False', 0, 2012)
# ('SOA Governance in Action', 'Jos Dirksen', None, 1, '1617290270', 'False', 0, 2012)
# ('RSS and Atom in Action', 'Dave Johnson', None, 1, '1932394494', 'False', 164, 2006)
# ('LDAP Programming, Management and Integration', 'Clayton Donley', None, 1, '1930110405', 'True', 149, 2002)
# ('Mule in Action', 'David Dossot', "John D'Emic", 2, '1933988967', 'False', 141, 2009)
# ('Java Foundation Classes', 'Stephen C. Drye', 'William C. Wake', 2, '1884777678', 'False', 143, 2001)
# ('Managing Components with Modeler', 'Vikram Goyal', None, 1, '1932394524k-e', 'False', 0, 2005)
# ('Command-line Processing with CLI', 'Vikram Goyal', None, 1, '1932394524l-e', 'False', 0, 2005)
# ('Understanding and Using Chain', 'Vikram Goyal', None, 1, '1932394524m-e', 'False', 0, 2005)
# ('Working with the Logging and Discovery Components', 'Vikram Goyal', None, 1, '1932394524n-e', 'False', 0, 2005)
# ('Uploading files with FileUpload', 'Vikram Goyal', None, 1, '1932394524b-e', 'False', 0, 2005)
# ('Handling Protocols with the Net Component', 'Vikram Goyal', None, 1, '1932394524c-e', 'False', 0, 2005)
# ('XML Parsing with Digester', 'Vikram Goyal', None, 1, '1932394524d-e', 'False', 0, 2005)
# ('JXPath and Betwixt: Working with XML', 'Vikram Goyal', None, 1, '1932394524e-e', 'False', 0, 2005)
# ('Validating Data with Validator', 'Vikram Goyal', None, 1, '1932394524f-e', 'False', 0, 2005)
# ('Enhancing Java Core Libraries with Collections', 'Vikram Goyal', None, 1, '1932394524g-e', 'False', 0, 2005)
# ('Enhancing Java Core Libraries with BeanUtils and Lang', 'Vikram Goyal', None, 1, '1932394524h-e', 'False', 0, 2005)
# ('Pool and DBCP: Creating and Using Object Pools', 'Vikram Goyal', None, 1, '1932394524i-e', 'False', 0, 2005)
# ('Python and Tkinter Programming', 'John E. Grayson', None, 1, '1884777813', 'False', 212, 2000)
# ('Microsoft.NET for Programmers', 'Fergal Grimes', None, 1, '1930110197', 'False', 120, 2002)
# ('Grails in Action', 'Glen Smith', 'Peter Ledbrook', 2, '1933988932', 'False', 147, 2009)
# ('Up to Speed with Swing, Second Edition', 'Steven Gutz', None, 1, '1884777759', 'False', 121, 1999)
# ('OSGi in Action', 'Richard S. Hall', 'Karl Pauls', 5, '1933988916', 'False', 314, 2011)
# ('GWT in Action', 'Robert Hanson', 'Adam Tacy', 2, '1933988231', 'False', 415, 2007)
# ('The Quick Python Book', 'Daryl Harms', 'Kenneth McDonald', 2, '1884777740', 'True', 237, 1999)
# ("SharePoint 2010 Site Owner's Manual", 'Yvonne M. Harryman', None, 1, '1933988754', 'False', 239, 2012)
# ('Java Development with Ant', 'Erik Hatcher', 'Steve Loughran', 2, '1930110588', 'False', 128, 2002)
# ('Lucene in Action', 'Erik Hatcher', 'Otis Gospodnetic', 2, '1932394281', 'False', 196, 2004)
# ('Lucene in Action, Second Edition', 'Erik Hatcher', 'Otis Gospodnetic', 4, '1933988177', 'False', 170, 2010)
# ('PowerBuilder 6.0 Questions & Answers', 'Tim Hatton', None, 1, '1884777708', 'False', 82, 1998)
# ('The Awesome Power of PowerJ', 'Tim Hatton', None, 1, '1884777538', 'False', 70, 1998)
# ('The Awesome Power of Power++', 'Tim Hatton', None, 1, '1884777546', 'False', 116, 1998)
# ('Azure in Action', 'Chris Hay', 'Brian H. Prince', 2, '193518248X', 'True', 272, 2010)
# ('Distributed Agile in Action', 'Vikas Hazrati', 'Balaji D Loganathan', 2, '1935182412', 'False', 212, None)
# ('Metaprogramming in .NET', 'Kevin Hazzard', 'Jason Bock', 2, '1617290262', 'False', 0, 2012)
# ('Portlets and Apache Portals', 'Stefan Hepper', 'Peter Fischer', 5, None, 'True', 153, 2005)
# ('Code Generation in Action', 'Jack Herrington', None, 1, '1930110979', 'False', 181, 2003)
# ('Illustrated Guide to HTTP', 'Paul S. Hethmon', None, 1, '138582262', 'False', 67, 1997)
# ('Agile ALM', 'Michael Hüttermann', None, 1, '1935182633', 'False', 276, 2011)
# ('Java Network Programming, Second Edition', 'Merlin Hughes', 'Michael Shoffner', 4, '188477749X', 'False', 136, 1999)
# ('Struts in Action', 'Ted N. Husted', 'Cedric Dumoulin', 4, '1932394249', 'True', 137, 2002)
# ('Camel in Action', 'Claus Ibsen', 'Jonathan Anstey', 2, '1935182366', 'False', 236, 2011)
# ('Taming Text', 'Grant S. Ingersoll', 'Thomas S. Morton', 4, '193398838X', 'False', 137, 2012)
# ('JBoss in Action', 'Javid Jamae', 'Peter Johnson', 2, '1933988029', 'False', 258, 2009)
# ('Gnuplot in Action', 'Philipp K. Janert', None, 1, '1933988398', 'True', 387, 2009)
# ('Extending and Embedding Perl', 'Tim Jenness', 'Simon Cozens', 2, '1930110820', 'False', 139, 2002)
# ('iOS 4 in Action', 'Jocelyn Harrington', 'Brandon Trebitowski', 5, '1617290017', 'False', 178, 2011)
# ('Elements of Programming with Perl', 'Andrew L. Johnson', None, 1, '1884777805', 'True', 176, 1999)
# ('Learn Windows PowerShell in a Month of Lunches', 'Don Jones', None, 1, '1617290211', 'False', 267, 2011)
# ('R in Action', 'Robert I. Kabacoff', None, 1, '1935182390', 'True', 241, 2011)
# ('Android in Practice', 'Matthias Kaeppler', 'Michael D. Galpin', 3, '9781935182924', 'False', 0, None)
# ('SOA Security', 'Ramarao Kanneganti', 'Prasad A. Chodavarapu', 2, '1932394680', 'False', 158, 2007)
# ('Rails 3 in Action', 'Ryan Bigg', 'Yehuda Katz', 2, '1935182277', 'False', 368, 2011)
# ('Continuous Integration in .NET', 'Marcin Kawalerowicz', 'Craig Berntson', 2, '1935182552', 'False', 309, 2011)
# ('Technology Paradise Lost', 'Erik Keller', None, 1, '1932394133', 'False', 295, 2004)
# ('Kermit 95+', 'Kermit Project at Columbia University', None, 1, '1930110057', 'False', 125, 2003)
# ('Laszlo in Action', 'Norman Klein', 'Max Carlson with Glenn MacEwen', 2, '1932394834', 'False', 287, 2008)
# ('Groovy in Action', 'Dierk Koenig with Andrew Glover', 'Paul King', 4, '1932394842', 'True', 235, 2007)
# ('Groovy in Action, Second Edition', 'Dierk König', 'Guillaume Laforge', 8, '1935182447', 'True', 289, None)
# ('Object Technology Centers of Excellence', 'Timothy D. Korson', 'Vijay K. Vaishnavi', 2, '132612313', 'False', 155, 1996)
# ('Test Driven', 'Lasse Koskela', None, 1, '1932394850', 'False', 152, 2007)
# ('Effective Unit Testing', 'Lasse Koskela', None, 1, '1935182579', 'False', 0, 2013)
# ('Making Java Groovy', 'Kenneth A. Kousen', None, 1, '1935182943', 'False', 192, 2013)
# ('The Awesome Power of Direct3D/DirectX', 'Peter J. Kovach', None, 1, '1884777473', 'False', 88, 2002)
# ('Practical Software Requirements', 'Benjamin L. Kovitz', None, 1, '1884777597', 'False', 131, 1998)
# ('NHibernate in Action', 'Pierre Henri Kuate', 'Tobin Harris', 5, '1932394923', 'False', 222, 2009)
# ('Microsoft Reporting Services in Action', 'Teo Lachev', None, 1, '1932394222', 'False', 217, 2004)
# ('AspectJ in Action', 'Ramnivas Laddad', None, 1, '1930110936', 'False', 260, 2003)
# ('AspectJ in Action, Second Edition', 'Ramnivas Laddad', None, 1, '1933988053', 'False', 161, 2009)
# ('Hadoop in Action', 'Chuck Lam', None, 1, '1935182196', 'True', 336, 2010)
# ('SQR in PeopleSoft and Other Applications', 'Galina', 'Vlad Landres', 2, '1884777775', 'False', 260, 2003)
# ('SQR in PeopleSoft and Other Applications, Second Edition', 'Galina Landres', 'Vlad Landres', 2, '1932394001', 'False', 148, 2003)
# ('F# in Action', 'Amanda Laucher', None, 1, '1935182250', 'False', 144, None)
# ('Tuscany SCA in Action', 'Simon Laws', 'Mark Combellack', 5, '1933988894', 'True', 245, 2011)
# ('Client/Server Yellow Pages', 'Compiled', 'introduced by Ted Lewis', 2, '1884777082', 'False', 204, 1995)
# ('Object Oriented Application Frameworks', 'Ted Lewis', 'friends', 2, '1884777066', 'False', 158, 1995)
# ('Tapestry in Action', 'Howard M. Lewis Ship', None, 1, '1932394117', 'False', 141, 2004)
# ('WebWork in Action', 'Patrick Lightbody', 'Jason Carreira', 2, '1932394532', 'False', 131, 2005)
# ('MacRuby in Action', 'Brendan G. Lim with Jerry Cheung', 'Jeremy McAnally', 2, '1935182498', 'False', 0, 2012)
# ('Erlang and OTP in Action', 'Martin Logan', 'Eric Merritt', 4, '1933988789', 'False', 208, 2010)
# ("SharePoint 2007 Developer's Guide to Business Data Catalog", 'Brett Lonsdale', 'Nick Swan', 2, '1933988819', 'True', 168, 2009)
# ('Doing IT Right', 'Harold Lorin', None, 1, '133964256', 'False', 256, 1995)
# ('Adobe AIR in Action', 'Joey Lott', 'Kathryn Rotondo', 4, '1933988487', 'False', 147, 2008)
# ('Ant in Action', 'Steve Loughran', 'Erik Hatcher', 2, '193239480X', 'False', 115, 2007)
# ('Restlet in Action', 'Jerome Louvel', 'Thierry Boileau', 4, '193518234X', 'False', 238, 2012)
# ('iText in Action', 'Bruno Lowagie', None, 1, '1932394796', 'False', 190, 2006)
# ('iText in Action, Second Edition', 'Bruno Lowagie', None, 1, '1935182617', 'False', 299, 2010)
# ('Power-3D', 'Kyle Lussier', None, 1, '138412146', 'False', 54, 1997)
# ('SNA and TCP/IP Enterprise Networking', 'Daniel C. Lynch', 'James P. Gray', 4, '131271687', 'False', 132, 1997)
# ('Subversion in Action', 'Jeffrey Machols', None, 1, '1932394478', 'False', 138, 2004)
# ('Minimal Perl', 'Tim Maher', None, 1, '1932394508', 'False', 155, 2006)
# ('Distributed Programming with Java', 'Qusay H. Mahmoud', None, 1, '1884777651', 'False', 78, 1999)
# ('Comprehensive Networking Glossary and Acronym Guide', 'Gary Scott Malkin', None, 1, '013319955X', 'False', 137, 1995)
# ('JavaServer Faces in Action', 'Kito D. Mann', None, 1, '1932394125', 'True', 130, 2004)
# ('LINQ in Action', 'Fabrice Marguerie', 'Steve Eichert', 3, '1933988169', 'True', 329, 2008)
# ('Internet BBSs', 'Richard Scott Mark', None, 1, '132869985', 'False', 150, 1996)
# ('Algorithms of the Intelligent Web', 'Haralambos Marmanis', 'Dmitry Babenko', 2, '1933988665', 'True', 187, 2009)
# ('JUnit in Action', 'Vincent Massol with Ted Husted', None, 1, '1930110995', 'False', 109, 2003)
# ('Tika in Action', 'Chris A. Mattmann', 'Jukka L. Zitting', 2, '1935182854', 'False', 0, 2011)
# ('Ruby in Practice', 'Jeremy McAnally', 'Assaf Arkin', 2, '1933988479', 'True', 134, 2009)
# ('Inside LotusScript', 'Joe McGinn', None, 1, '1884777481', 'False', 79, 1997)
# ('Maximum MIDI', 'Paul Messick', None, 1, '1884777449', 'False', 169, 1997)
# ('Planning and Managing ATM Networks', 'Daniel Minoli', 'Thomas W. Golway', 4, '132621894', 'False', 89, 1997)
# ('Client/Server Applications on ATM Networks', 'Daniel Minoli', 'Andrew Schmidt', 2, '137353006', 'False', 93, 1997)
# ('JavaFX in Action', 'Simon Morris', None, 1, '1933988991', 'False', 263, 2009)
# ('Entity Framework 4 in Action', 'Stefano Mostarda', 'Marco De Sanctis', 4, '1935182188', 'True', 178, 2011)
# ('ASP.NET 2.0 Web Parts in Action', 'Darren Neimke', None, 1, '193239477X', 'False', 178, 2006)
# ('Sass and Compass in Action', 'Wynn Netherland', 'Nathan Weizenbaum', 5, '1617290149', 'False', 284, 2013)
# ('Core OWL 5.0', 'Ted Neward', None, 1, '1884777503', 'False', 83, 1997)
# ('Advanced OWL 5.0', 'Ted Neward', None, 1, '1884777465', 'False', 103, 1998)
# ('Server-Based Java Programming', 'Ted Neward', None, 1, '1884777716', 'False', 147, 2000)
# ('SQL Server MVP Deep Dives', 'Contributions from 53 SQL Server MVPs', 'Edited by Paul Nielsen', 8, '1935182048', 'True', 163, 2009)
# ('SQL Server MVP Deep Dives', 'Contributions from 53 SQL Server MVPs; Edited by Paul Nielsen', 'Kalen Delaney', 7, '9781935182047', 'True', 100, 2009)
# ('SQL Server MVP Deep Dives', 'Paul Nielsen', 'Kalen Delaney', 7, '9781935182047', 'False', 0, 2009)
# ('PostGIS in Action', 'Regina O. Obe', 'Leo S. Hsu', 2, '1935182269', 'False', 178, 2011)
# ('Programming Mac OS X', "Kevin O'Malley", None, 1, '1930110855', 'False', 98, 2003)
# ('The Art of Unit Testing', 'Roy Osherove', None, 1, '1933988274', 'False', 142, 2009)
# ('Mahout in Action', 'Sean Owen', 'Robin Anil', 5, '1935182684', 'False', 0, 2011)
# ('ASP.NET MVC in Action', 'Jeffrey Palermo', 'Ben Scheirman', 4, '1933988622', 'False', 111, 2009)
# ('ASP.NET MVC 2 in Action', 'Jeffrey Palermo', 'Ben Scheirman', 6, '193518279X', 'True', 291, 2010)
# ('ASP.NET MVC 4 in Action', 'Jeffrey Palermo', 'Jimmy Bogard', 6, '1617290416', 'True', 277, 2012)
# ('EJB 3 in Action', 'Debu Panda', 'Reza Rahman', 3, '1933988347', 'False', 169, 2007)
# ('EJB 3 in Action, Second Edition', 'Debu Panda', 'Reza Rahman', 5, '1935182994', 'False', 170, 2014)
# ("Explorer's Guide to the Semantic Web", 'Thomas B. Passin', None, 1, '1932394206', 'True', 183, 2004)
# ('Practical LotusScript', 'Anthony Patton', None, 1, '1884777767', 'False', 82, 1999)
# ('Domino Development with Java', 'Anthony Patton', None, 1, '1930110049', 'False', 76, 2000)
# ('Windows PowerShell in Action', 'Bruce Payette', None, 1, '1932394907', 'False', 208, 2007)
# ('Windows PowerShell in Action, Second Edition', 'Bruce Payette', None, 1, '1935182137', 'False', 230, 2011)
# ('Silverlight 4 in Action, Revised Edition', 'Pete Brown', None, 1, '1935182374', 'False', 318, 2010)
# ('Silverlight 5 in Action', 'Pete Brown', None, 1, '1617290319', 'False', 0, 2012)
# ('Hibernate Quickly', 'Patrick Peak', 'Nick Heudecker', 2, '1932394419', 'False', 151, 2005)
# ('Generative Art', 'Matt Pearson', None, 1, '1935182625', 'False', 0, 2011)
# ('Windows Phone 7 in Action', 'Timothy Binkley-Jones', 'Massimo Perga', 4, '1617290092', 'False', 311, 2012)
# ('Lift in Action', 'Timothy Perrett', None, 1, '1935182803', 'False', 0, 2011)
# ('Web Development with Apache and Perl', 'Theo Petersen', None, 1, '1930110065', 'False', 168, 2002)
# ('Real-World Functional Programming', 'Tomas Petricek with Jon Skeet', None, 1, '1933988924', 'False', 144, 2009)
# ('Machine Learning in Action', 'Peter Harrington', None, 1, '1617290181', 'True', 239, 2012)
# ('Dependency Injection', 'Dhanji R. Prasanna', None, 1, '193398855X', 'False', 110, 2009)
# ('Understanding Enterprise SOA', 'Eric Pulier and Hugh Taylor', 'Foreword by Paul Gaffney', 2, '1932394591', 'False', 132, 2005)
# ('Open-Source ESBs in Action', 'Tijs Rademakers', 'Jos Dirksen', 2, '1933988215', 'False', 199, 2008)
# ('Activiti in Action', 'Tijs Rademakers', None, 1, '1617290122', 'False', 0, 2012)
# ('DSLs in Boo: Domain-Specific Languages in .NET', 'Oren Eini writing as Ayende Rahien', None, 1, '1933988606', 'False', 182, 2010)
# ('JUnit Recipes', 'J. B. Rainsberger with contributions by Scott Stirling', None, 1, '1932394230', 'True', 182, 2004)
# ('wxPython in Action', 'Noel Rappin', 'Robin Dunn', 2, '1932394621', 'False', 251, 2006)
# ('Clojure in Action', 'Amit Rathore', None, 1, '1935182595', 'False', 295, 2011)
# ('Scala in Action', 'Nilanjan Raychaudhuri', None, 1, '1935182757', 'False', 0, 2013)
# ('Working with Objects', 'Trygve Reenskaug', None, 1, '134529308', 'False', 226, 1995)
# ('PHP in Action', 'Dagfinn Reiersøl with Marcus Baker', 'Chris Shiflett', 2, '1932394753', 'False', 136, 2007)
# ('Secrets of the JavaScript Ninja', 'John Resig', None, 1, '193398869X', 'False', 238, 2012)
# ('Microsoft Office Essentials', 'Ronny Richardson', None, 1, '132623129', 'True', 145, 1996)
# ('Swing', 'Matthew Robinson', 'Pavel Vorobiev', 2, '1884777848', 'False', 0, 1999)
# ('Swing Second Edition', None, None, 0, '193011088X', 'False', 137, 2003)
# ('The Awesome Power of Java Beans', 'Lawrence H. Rodrigues', None, 1, '1884777562', 'False', 106, 1998)
# ('Personal Videoconferencing', 'Evan Rosen', None, 1, '013268327X', 'False', 72, 1996)
# ('The Cloud at Your Service', 'Jothy Rosenberg', 'Arthur Mateos', 2, '1935182528', 'False', 0, 2010)
# ('Implementing Elliptic Curve Cryptography', 'Michael Rosing', None, 1, '1884777694', 'False', 156, 1998)
# ('SOA Patterns', 'Arnon Rotem-Gal-Oz', None, 1, '1933988266', 'True', 327, 2012)
# ('Hello World!', 'Warren D. Sande', 'Carter Sande', 2, '1933988495', 'False', 153, 2009)
# ('SCBCD Exam Study Kit', 'Paul Sanghera', None, 1, '1932394400', 'False', 161, 2005)
# ('Portlets in Action', 'Ashish Sarin', None, 1, '1935182544', 'False', 199, 2011)
# ('SWT/JFace in Action', 'Matthew Scarpino', 'Stephen Holder', 5, '1932394273', 'False', 154, 2004)
# ('OpenCL in Action', 'Matthew Scarpino', None, 1, '1617290173', 'False', 0, 2011)
# ('Multiprotocol over ATM', 'Andrew Schmidt', 'Daniel Minoli', 2, '138892709', 'False', 72, 1998)
# ('Dependency Injection in .NET', 'Mark Seemann', None, 1, '1935182501', 'False', 286, 2011)
# ('Java 3D Programming', 'Daniel Selman', None, 1, '1930110359', 'False', 227, 2002)
# ('Liferay in Action', 'Richard Sezov', 'Jr', 2, '193518282X', 'False', 0, 2011)
# ('JSP Tag Libraries', 'Gal Shachor', 'Adam Chace', 3, '193011009X', 'False', 179, 2001)
# ('Instant Messaging in Java', 'Iain Shigeoka', None, 1, '1930110464', 'True', 198, 2002)
# ('Java Applets and Channels Without Programming', 'Ronny Richardson', 'Michael Shoffner', 6, '1884777392', 'False', 256, 1999)
# ('PowerShell in Practice', 'Richard Siddaway', None, 1, '1935182005', 'False', 249, 2010)
# ('PowerShell and WMI', 'Richard Siddaway', None, 1, '1617290114', 'False', 0, 2012)
# ('Making Sense of Java', 'Bruce Simpson', 'John Mitchell', 6, '132632942', 'False', 80, 1996)
# ('C++/CLI in Action', 'Nishant Sivakumar', None, 1, '1932394818', 'False', 151, 2007)
# ('C# in Depth', 'Jon Skeet', None, 1, '1933988363', 'True', 156, 2008)
# ('C# in Depth, Second Edition', 'Jon Skeet', None, 1, '1935182471', 'False', 171, None)
# ('Magical A-Life Avatars', 'Peter Small', None, 1, '1884777589', 'False', 110, 2000)
# ('Becoming Agile', 'Greg Smith', 'Ahmed Sidky', 2, '1933988258', 'False', 266, 2009)
# ('ActiveMQ in Action', 'Bruce Snyder', 'Dejan Bosanac', 4, '1933988940', 'False', 264, 2011)
# ('Implementing PeopleSoft Financials', 'Early Stephens', None, 1, '138411808', 'False', 107, 1997)
# ('SQL Server DMVs in Action', 'Ian W. Stirk', None, 1, '1935182730', 'True', 174, 2011)
# ('Scala in Depth', 'Joshua D. Suereth', None, 1, '1935182706', 'False', 265, 2012)
# ('JMX in Action', 'Benjamin G. Sullins', 'Mark B. Whipple', 2, '1930110561', 'False', 128, 2002)
# ('EJB Cookbook', 'Benjamin G. Sullins', 'Mark B. Whipple', 2, '1930110944', 'False', 94, 2003)
# ('GWT in Action, Second Edition', 'Adam Tacy', 'Robert Hanson', 5, '1935182846', 'False', 0, 2013)
# ('JUnit in Action, Second Edition', 'Petar Tahchiev', 'Felipe Leme', 5, '1935182021', 'False', 259, 2010)
# ('Bitter Java', 'Bruce A. Tate', None, 1, '193011043X', 'False', 148, 2002)
# ('Bitter EJB', 'Bruce Tate', 'Mike Clark', 4, '1930110952', 'False', 184, 2003)
# ('Spring Batch in Action', 'Arnaud Cogoluegnes', 'Thierry Templier', 4, '1935182951', 'False', 0, 2011)
# ('JDK 1.4 Tutorial', 'Gregory M. Travis', None, 1, '1930110456', 'False', 149, 2002)
# ('iPhone and iPad in Action', 'Brandon Trebitowski', 'Christopher Allen', 4, '1935182587', 'False', 86, 2010)
# ('SQL Server 2005 Reporting Services in Action', 'Bret Updegraff', None, 1, '1932394761', 'True', 187, 2006)
# ('Ten Years of UserFriendly.Org', 'JD "Illiad" Frazer', None, 1, '1935182129', 'False', 103, 2008)
# ('Graphics Programming with Perl', 'Martien Verbruggen', None, 1, '1930110022', 'False', 143, 2002)
# ('RabbitMQ in Action', 'Alvaro Videla', 'Jason J.W. Williams', 2, '1935182978', 'False', 0, 2012)
# ('XDoclet in Action', 'Craig Walls', 'Norman Richards', 2, '1932394052', 'False', 160, 2003)
# ('Spring in Action', 'Craig Walls', 'Ryan Breidenbach', 2, '1932394354', 'False', 166, 2005)
# ('Spring in Action, Second Edition', 'Craig Walls with Ryan Breidenbach', None, 1, '1933988134', 'False', 153, 2007)
# ('Spring in Action, Third Edition', 'Craig Walls', None, 1, '1935182358', 'False', 289, 2011)
# ('Spring in Practice', 'Willie Wheeler with Joshua White', None, 1, '1935182056', 'False', 360, 2013)
# ('Java 2 Micro Edition', 'James P. White', 'David A. Hemphill', 2, '1930110332', 'True', 107, 2002)
# ('SharePoint 2010 Workflows in Action', 'Phil Wicklund', None, 1, '1935182714', 'True', 112, 2011)
# ('SharePoint 2010 Web Parts in Action', 'Wictor Wilén', None, 1, '1935182773', 'False', 102, 2011)
# ('C++ Concurrency in Action', 'Anthony Williams', None, 1, '1933988770', 'False', 278, 2012)
# ('Java Servlets by Example', 'Alan R. Williamson', None, 1, '188477766X', 'False', 172, 2002)
# ('XML Programming with VB and ASP', 'Mark Wilson', 'Tracey Wilson', 2, '1884777872', 'True', 80, 1999)
# ('Oracle8i Database Administration', 'Noel Yuhanna', None, 1, '1884777783', 'True', 152, 1999)
# ('The Engaging Web', 'Gabe Zichermann', 'Chris Cunningham', 2, '9781935182078', 'False', 345, None)
# ('Enterprise OSGi In Action', 'Holly Cummins', 'Timothy Ward', 2, '1617290130', 'False', 0, None)
# ('Ext JS in Action, Second Edition', 'Jesus Garcia', 'Grgur Grisogono', 4, '1617290327', 'False', 0, 2014)
# ('Android in Action, Third Edition', 'W. Frank Ableson', 'Robi Sen', 4, '1617290505', 'False', 0, 2011)
# ('Arduino in Action', 'Martin Evans', 'Joshua Noble', 4, '1617290246', 'False', 181, 2013)
# ('Node.js in Action', 'Mike Cantelon', 'Marc Harter', 5, '1617290572', 'True', 292, 2013)
# ('Third-Party JavaScript ', 'Ben Vinegar', 'Anton Kovalyov', 2, '1617290548', 'False', 0, 2013)
# ('Multimedia Computing', 'Matthew E. Hodges', None, 1, '020152029X', 'False', 0, 1993)
# ('Web Development with JavaServer Pages', 'Duane K. Fields', 'Mark A. Kolb', 2, '1884777996', 'False', 0, 2000)
# ('Up to Speed with Swing', 'Steven J. Gutz', None, 1, '1884777643', 'False', 0, 1998)
# ("Manager's Guide to Open Source", 'Maria Winslow', None, 1, '193239429X', 'False', 0, 2004)
# ('Programming Web Services with Java', 'Ajamu A. Wesley', None, 1, '1930110421', 'False', 0, 2002)
# ('TCP/IP Programming for OS/2', 'Steven J. Gutz', None, 1, '132612496', 'False', 0, 1996)
# ('Implementing SAP R/3, Second Edition', None, None, 0, '013889213X', 'False', 0, 1997)
# ('Implementing SAP R/3', None, None, 0, '1884777228', 'False', 0, 1996)
# ('Using C-Kermit: Communication Software', None, None, 0, '1884777147', 'False', 0, None)
# ('SCWCD Exam Study Kit', 'Hanumant Deshmukh', 'Jignesh Malavia', 2, '1930110596', 'False', 0, 2002)
# ('Unit Testing in C++', 'Bruce Trask', 'Angel Roman', 2, '1617290386', 'False', 0, None)
# ('Big Data', 'Nathan Marz', 'James Warren', 2, '1617290343', 'False', 0, None)
# ('CoffeeScript in Action', 'Patrick Lee', None, 1, '1617290629', 'False', 0, 2014)
# ('SQL Server MVP Deep Dives, Volume 2', 'Kalen Delaney', 'Louis Davidson', 8, '1617290475', 'False', 0, 2011)
# ('HTML5 in Action', 'Rob Crowther', 'Joe Lennon', 5, '1617290491', 'False', 213, 2014)
# ('Java Persistence with Hibernate, Second Edition', 'Christian Bauer', 'Gavin King', 4, '1617290459', 'False', 0, None)
# ('Hadoop in Practice', 'Alex Holmes', None, 1, '1617290238', 'False', 0, 2012)
# ('HBase in Action', 'Nicholas Dimiduk', 'Amandeep Khurana', 2, '1617290521', 'False', 0, 2012)
# ('Flex Mobile in Action', 'Jonathan Campos', None, 1, '1617290610', 'False', 0, 2012)
# ('HTML5 for .NET Developers', 'Jim Jackson', 'II', 3, '1617290432', 'False', 0, 2012)
# ('50 Android Hacks', 'Carlos M. Sessa', None, 1, '1617290564', 'False', 0, 2013)
# ('PowerShell in Depth', 'Don Jones', 'Richard Siddaway', 4, '1617290556', 'False', 0, 2013)
# ('Augmented Reality Revealed', 'Robert A. Rice Jr.', None, 1, '1617290165', 'False', 0, None)
# ('Building Well-Structured JavaScript Applications', 'Julio C. Ody', None, 1, '1617290599', 'False', 0, None)
# ('Linked Data', 'David Wood', 'Marsha Zaidman', 4, '1617290394', 'False', 0, 2013)
# ('Mule in Action, Second Edition', 'David Dossot', "John D'Emic", 4, '1617290823', 'False', 0, 2014)
# ('Single Page Web Applications', 'Michael S. Mikowski', 'Josh C. Powell', 2, '1617290750', 'False', 0, 2013)
# ('The Art of Unit Testing, Second Edition', 'Roy Osherove', None, 1, '1617290890', 'False', 0, 2013)
# ('Play for Java', 'Nicolas Leroux', 'Sietse de Kaper', 2, '1617290904', 'False', 0, 2014)
# ('Hello World! Second Edition', 'Warren Sande', 'Carter Sande', 2, '1617290920', 'False', 0, 2013)
# ('Dart in Action', 'Chris Buckett', None, 1, '1617290866', 'False', 0, 2012)
# ('Redis in Action', 'Josiah Carlson', None, 1, '1617290858', 'False', 0, 2013)
# ('Using the TI-83 Plus/TI-84 Plus', 'Christopher R. Mitchell', None, 1, '161729084X', 'False', 0, 2013)
# ('Neo4j in Action', 'Jonas Partner', 'Aleksa Vukotic', 4, '1617290769', 'False', 0, None)
# ('Programming the TI-83 Plus/TI-84 Plus', 'Christopher R. Mitchell', None, 1, '1617290777', 'False', 0, 2012)
# ('Functional Programming in Scala', 'Paul Chiusano', 'Rúnar Bjarnason', 2, '1617290653', 'False', 0, None)
# ('Play for Scala', 'Peter Hilton', 'Erik Bakker', 4, '1617290793', 'False', 0, 2013)
# ('Node.js in Practice', 'Alex Young', 'Marc Harter', 2, '1617290939', 'False', 0, None)
# ('SonarQube in Action', 'G. Ann Campbell', 'Patroklos P. Papapetrou', 2, '1617290955', 'False', 0, 2013)
# ('Windows Store App Development: C# and XAML', 'Peter M. Brown', None, 1, '1617290947', 'False', 0, 2013)
# ('Learn Windows IIS in a Month of Lunches', 'Jason C. Helmick', None, 1, '1617290971', 'False', 0, 2013)
# ('Mondrian in Action', 'William Back', 'Nicholas Goodman', 4, '161729098X', 'False', 0, None)
# ('RabbitMQ in Depth', 'Gavin M. Roy', None, 1, '1617291005', 'False', 0, None)
# ('Akka in Action', 'Raymond Roestenburg', 'Rob Bakker', 4, '1617291013', 'False', 0, None)
# ('Extending jQuery', 'Keith B. Wood', None, 1, '161729103X', 'False', 0, 2013)
# ('OCA Java SE 7 Programmer I Certification Guide', 'Mala Gupta', None, 1, '1617291048', 'False', 0, 2013)
# ('Kanban in Action', 'Marcus Hammarberg', 'Joakim Sunden', 2, '1617291056', 'False', 0, 2014)
# ('Solr in Action', 'Trey Grainger', 'Timothy Potter', 2, '1617291021', 'False', 0, 2014)
# ('Making Sense of NoSQL', 'Daniel G. McCreary', 'Ann M. Kelly', 2, '1617291072', 'False', 0, 2013)
# ('Jaguar Development with PowerBuilder 7', 'MIchael Barlotta', None, 1, '1884777864', 'False', 0, 1999)
# ('Grails in Action, Second Edition', 'Glen Smith', 'Peter Ledbrook', 2, '1617290963', 'False', 0, None)
# ('Rails 4 in Action', 'Ryan Bigg', 'Yehuda Katz', 4, '1617291099', 'False', 0, None)
# ('Learn Windows PowerShell in a Month of Lunches, Second Edition', 'Don Jones', 'Jeffery D. Hicks', 2, '1617291080', 'False', 0, 2012)
# ('AOP in .NET', 'Matthew D. Groves', None, 1, '1617291145', 'False', 0, 2013)
# ('Learn PowerShell Toolmaking in a Month of Lunches', 'Don Jones', 'Jeffery Hicks', 2, '1617291161', 'False', 0, 2012)
# ('CMIS and Apache Chemistry in Action', 'Florian Müller', 'Jay Brown', 3, '1617291153', 'False', 0, None)
# ('Action Guide (aka VB .NET)', 'Paul Messick', None, 1, '1930110324', 'False', 0, None)
# ('Learn Active Directory Management in a Month of Lunches', 'Richard Siddaway', None, 1, '1617291196', 'False', 0, None)
# ('Spring in Action, Fourth Edition', 'Craig Walls', None, 1, '161729120X', 'False', 0, None)
# ('The Mikado Method', 'Ola Ellnestam', 'Daniel Brolund', 2, '1617291218', 'False', 0, 2014)
# ('The Responsive Web', 'Matthew Carver', None, 1, '1617291242', 'False', 0, None)
# ('Fast ASP.NET Websites', 'Dean Alan Hume', None, 1, '1617291250', 'False', 0, 2013)
# ('SBT in Action', 'Joshua Suereth', 'Matthew Farwell', 2, '1617291277', 'False', 0, None)
# ('PowerShell Deep Dives', 'Edited by Jeffery Hicks', 'Richard Siddaway', 5, '1617291315', 'False', 0, None)
# ('Gradle in Action', 'Benjamin Muschko', None, 1, '1617291307', 'False', 0, 2014)
# ('Scalatra in Action', 'Ivan Porto Carrero', 'Ross A. Baker', 6, '1617291293', 'False', 0, None)
# ('AngularJS in Action', 'Brian Ford', 'Lukas Ruebbelke', 2, '1617291331', 'False', 0, None)
# ('Software Development Metrics', 'David Nicolette', None, 1, '1617291358', 'False', 0, None)
# ('F# Deep Dives', 'Tomas Petricek', 'Phillip Trelford', 2, '1617291323', 'False', 0, None)
# ('C# in Depth, Third Edition', 'Jon Skeet', None, 1, '161729134X', 'False', 0, 2013)
# ('PostGIS in Action, Second Edition', 'Regina Obe', 'Leo Hsu', 2, '1617291390', 'False', 0, None)
# ('R in Action, Second Edition', 'Robert Kabacoff', None, 1, '1617291382', 'False', 0, None)
# ('The Joy of Clojure, Second Edition', 'Michael Fogus', 'Chris Houser', 2, '1617291412', 'False', 0, 2014)
# ('iOS 7 in Action', 'Brendan G. Lim', 'Martin Conte Mac Donell', 2, '1617291420', 'False', 0, 2014)
# ('Hello App Inventor!', 'Paula Beer', 'Carl Simmons', 2, '1617291439', 'False', 0, None)
# ('Ember.js in Action', 'Joachim Haagen Skeie', None, 1, '1617291455', 'False', 0, 2014)
# ('Netty in Action', 'Norman Maurer', 'Courtney Robinson', 2, '1617291471', 'False', 0, None)
# ('RavenDB in Action', 'Itamar Syn-Hershko', None, 1, '1617291501', 'False', 0, None)
# ('OCP Java SE 7 Programmer II Certification Guide', 'Mala Gupta', None, 1, '161729148X', 'False', 0, None)
# ('Backbone.js in Action', 'Samuel M. Breed', 'Cole Krumbholz', 4, '1617291536', 'False', 0, None)
# ('Clojure in Action, Second Edition', 'Amit Rathore', None, 1, '1617291528', 'False', 0, None)
# ('Practical Data Science with R', 'Nina Zumel', 'John Mount', 2, '1617291560', 'False', 0, 2014)
# ('Secrets of the JavaScript Ninja pBook upgrade', None, None, 0, None, 'False', 0, None)
# ('ArcGIS Web Development', 'Rene Rubalcava', None, 1, '1617291617', 'False', 0, None)
# ('Elasticsearch in Action', 'Radu Gheorghe', 'Matthew Lee Hinman', 2, '1617291625', 'False', 0, None)
# ('Learn SCCM 2012 in a Month of Lunches', 'James Bannan', None, 1, '1617291684', 'False', 0, None)
# ('Programming for Musicians and Digital Artists', 'Ajay Kapur', 'Perry Cook', 5, '1617291706', 'False', 0, None)
# ('BDD in Action', 'John F. Smart', None, 1, '161729165X', 'False', 0, None)
# ('Windows Phone 8 in Action', 'Timothy Binkley-Jones', 'Massimo Perga', 4, '1617291374', 'False', 0, 2013)
# ('Titanium Alloy in Action', 'Ricardo Alcocer', None, 1, '1617291749', 'False', 0, None)
# ('Giraph in Action', 'Claudio Martella', 'Roman Shaposhnik', 4, '1617291757', 'False', 0, None)
# ('The Well-Grounded Rubyist, Second Edition', 'David A. Black', None, 1, '1617291692', 'False', 0, 2014)
# ('Go in Action', 'Brian Ketelsen', 'Erik St. Martin', 4, '1617291781', 'False', 0, None)
# ("The Programmer's Guide to Apache Thrift ", 'Randy Abernethy', None, 1, '1617291811', 'False', 0, None)
# ('Grokking Functional Programming', 'Aslam Khan', None, 1, '1617291838', 'False', 0, None)
# ('CORS in Action', 'Monsur Hossain', None, 1, '161729182X', 'False', 0, None)
# ('Reactive Design Patterns', 'Roland Kuhn', 'Jamie Allen', 2, '1617291803', 'False', 0, None)
# ('Storm Applied', 'Sean Allen', 'Peter Pathirana', 4, '1617291897', 'False', 0, None)
# ('Real-World Machine Learning', 'Henrik Brink', 'Joseph Richards', 2, '1617291927', 'False', 0, None)
# ('jQuery UI in Action', 'Theodore J. (T.J.) VanToll III', None, 1, '1617291935', 'False', 0, None)
# ('Web Components in Action', 'Chris Buckett', None, 1, '1617291943', 'False', 0, None)
# ('JavaScript Application Design', 'Nicolas G. Bevacqua', None, 1, '1617291951', 'False', 0, None)
# ('Git in Practice', 'Mike McQuaid', None, 1, '1617291978', 'False', 0, None)
# ('Impala in Action', 'Richard L. Saltzer', 'Istvan Szegedi', 2, '1617291986', 'False', 0, None)
# ('Java 8 in Action', 'Raoul-Gabriel Urma', 'Mario Fusco', 4, '1617291994', 'False', 0, None)
# ('Elixir in Action', 'Saša Juric´', None, 1, '161729201X', 'False', 0, None)
# ('MongoDB in Action, Second Edition', 'Kyle Banker', 'Peter Bakkum', 6, '1617291609', 'False', 0, None)
# ('Getting MEAN with Mongo, Express, Angular, and Node', 'Simon Holmes', None, 1, '1617292036', 'False', 0, None)
# ('jQuery in Action, Third Edition', 'Bear Bibeault', 'Yehuda Katz', 4, '1617292079', 'False', 0, None)
# ('D3.js in Action', 'Elijah Meeks', None, 1, '1617292117', 'False', 0, None)
# ('Learn SQL Server Administration in a Month of Lunches', 'Don Jones', None, 1, '1617292133', 'False', 0, 2014)
# ('Geoprocessing with Python', 'Chris Garrard', None, 1, '1617292141', 'False', 0, None)
# ('Barcodes with iOS', 'Oliver Drobnik', None, 1, '161729215X', 'False', 0, None)
# ('Chef in Action', 'Dimitri Aivaliotis', None, 1, '1617292214', 'False', 0, None)
# ('Hadoop in Practice, Second Edition', 'Alex Holmes', None, 1, '1617292222', 'False', 0, None)
# ('Oculus Rift in Action', 'Bradley Austin Davis', 'Karen Bryla', 4, '1617292192', 'False', 0, None)
# ('OpenStack in Action', 'Cody Bumgardner', None, 1, '1617292168', 'False', 0, None)
# ('PowerShell in Depth, Second Edition', 'Don Jones', 'Jeffery Hicks', 4, '1617292184', 'False', 0, None)
# ('Practical Probabilistic Programming', 'Avi Pfeffer', None, 1, '1617292338', 'False', 0, None)
# ('Unity in Action', 'Joseph Hocking', None, 1, '161729232X', 'False', 0, None)
# ('Express.js in Action', 'Evan M. Hahn', None, 1, '1617292427', 'False', 0, None)
# ('Learn Git in a Month of Lunches', 'Rick Umali', None, 1, '1617292419', 'False', 0, None)
# ('Understanding SPAs', 'Emmit A. Scott', 'Jr.', 2, '1617292435', 'False', 0, None)
# ('XSLT Quickly', None, None, 0, '1930110111', 'False', 183, 2001)
# ('Windows Forms Programming with C#', None, None, 0, '1930110286', 'True', 137, 2002)
# ('Windows Forms in Action', None, None, 0, '1932394656', 'True', 117, 2006)
# ('Event Processing in Action', None, None, 0, '1935182218', 'False', 306, 2010)
# ('The Well-Grounded Java Developer', None, None, 0, '1617290068', 'True', 179, 2012)
# ('Objective-C Fundamentals', None, None, 0, '1935182536', 'False', 292, 2011)
# ('ADO.NET Programming', None, None, 0, '1930110294', 'True', 117, 2002)
# ('WPF in Action with Visual Studio 2008', None, None, 0, '1933988223', 'False', 294, 2008)
# ('Location-Aware Applications', None, None, 0, '1935182331', 'False', 0, 2011)
# ('Web Development with JavaServer Pages, Second Edition', None, None, 0, '193011012X', 'False', 180, 2001)
# ('IntelliJ IDEA in Action', None, None, 0, '1932394443', 'False', 188, 2006)
# ('Spring Integration in Action', None, None, 0, '1935182439', 'False', 235, 2012)
# ('The Joy of Clojure', None, None, 0, '1935182641', 'True', 146, 2011)
# ('Dynamic WAP Application Development', None, None, 0, '1930110081', 'False', 247, 2002)
# ('IronPython in Action', None, None, 0, '1933988339', 'False', 301, 2009)
# ('Art of Java Web Development', None, None, 0, '1932394060', 'False', 193, 2003)
# ('Java Reflection in Action', None, None, 0, '1932394184', 'False', 163, 2004)
# ('Programming Windows Server 2003', None, None, 0, '1930110987', 'False', 141, 2003)
# ('Struts Recipes', None, None, 0, '1932394249', 'False', 112, 2004)
# ('Hello! iOS Development', None, None, 0, '1935182986', 'False', 0, 2013)
# ('Jess in Action', None, None, 0, '1930110898', 'False', 176, 2003)
# ('Remote LAN Access', None, None, 0, '134944518', 'False', 69, 1996)
# ('J2EE and XML Development', None, None, 0, '1930110308', 'False', 97, 2002)
# ('Eclipse in Action', None, None, 0, '1930110960', 'False', 204, 2003)
# ('ASP.NET AJAX in Action', None, None, 0, '1933988142', 'False', 291, 2007)
# ('Ext JS in Action', None, None, 0, '1935182110', 'True', 263, 2010)
# ('Sencha Touch in Action', None, None, 0, '1617290378', 'False', 162, 2013)
# ('DSLs in Action', None, None, 0, '1935182455', 'False', 374, 2010)
# ('Database Programming for Handheld Devices', None, None, 0, '1884777856', 'False', 0, 2000)
# ('Jakarta Commons Online Bookshelf', None, None, 0, '1932394524', 'False', 190, 2005)
# ('Browsing with HttpClient', None, None, 0, '1932394524a-e', 'False', 0, 2005)
# ('Codec: Encoders and Decoders', None, None, 0, '1932394524j-e', 'False', 0, 2005)

# %% [markdown]
# 2. Save the content of `rows` in a SQL-like table using `sqlite3`, and choose the appropriate column types.
#
#   As your column names use the following:
#
#   - `title`
#   - `author_1`
#   - `author_2`
#   - `num_authors`
#   - `isbn`
#   - `has_data`
#   - `desc_len`
#   - `year_published`

# %%
import sqlite3

connection = sqlite3.connect(':memory:')
cursor = connection.cursor()

cursor.execute('''CREATE TABLE books
             (title text, author_1 text, author_2 text, num_author int, isbn text, has_data text, desc_len int, year_published int) ''')
cursor.executemany('INSERT INTO books VALUES (?,?,?,?,?,?,?,?)',all_books_info)

# %% [markdown]
# 3. Write a SQL query against the table to show all books that (1) contain the word "data" and (2) have more than 3 authors. Store the result of the query in an object called `books_table`, then close the connection.

# %%
books_table = []
for row in connection.cursor().execute('SELECT * FROM books where has_data = "True" AND num_author >= 3;'):
    books_table.append(row)
    print(row)
books_table
connection.commit()
connection.close()
# Out:
# ('Unlocking Android', 'W. Frank Ableson', 'Charlie Collins', 3, '1933988673', 'True', 252, 2009)
# ('Flex 4 in Action', 'Tariq Ahmed', 'Dan Orlando', 4, '1935182420', 'True', 329, 2010)
# ('iBATIS in Action', 'Clinton Begin', 'Brandon Goodin', 3, '1932394826', 'True', 159, 2007)
# ('Spring Dynamic Modules in Action', 'Arnaud Cogoluegnes', 'Thierry Templier', 4, '1935182307', 'True', 183, 2010)
# ('Portlets and Apache Portals', 'Stefan Hepper', 'Peter Fischer', 5, None, 'True', 153, 2005)
# ('Struts in Action', 'Ted N. Husted', 'Cedric Dumoulin', 4, '1932394249', 'True', 137, 2002)
# ('Groovy in Action', 'Dierk Koenig with Andrew Glover', 'Paul King', 4, '1932394842', 'True', 235, 2007)
# ('Groovy in Action, Second Edition', 'Dierk König', 'Guillaume Laforge', 8, '1935182447', 'True', 289, None)
# ('Tuscany SCA in Action', 'Simon Laws', 'Mark Combellack', 5, '1933988894', 'True', 245, 2011)
# ('LINQ in Action', 'Fabrice Marguerie', 'Steve Eichert', 3, '1933988169', 'True', 329, 2008)
# ('Entity Framework 4 in Action', 'Stefano Mostarda', 'Marco De Sanctis', 4, '1935182188', 'True', 178, 2011)
# ('SQL Server MVP Deep Dives', 'Contributions from 53 SQL Server MVPs', 'Edited by Paul Nielsen', 8, '1935182048', 'True', 163, 2009)
# ('SQL Server MVP Deep Dives', 'Contributions from 53 SQL Server MVPs; Edited by Paul Nielsen', 'Kalen Delaney', 7, '9781935182047', 'True', 100, 2009)
# ('ASP.NET MVC 2 in Action', 'Jeffrey Palermo', 'Ben Scheirman', 6, '193518279X', 'True', 291, 2010)
# ('ASP.NET MVC 4 in Action', 'Jeffrey Palermo', 'Jimmy Bogard', 6, '1617290416', 'True', 277, 2012)
# ('Node.js in Action', 'Mike Cantelon', 'Marc Harter', 5, '1617290572', 'True', 292, 2013)

# %% [markdown]
# SQL tables are not the only way, and definitely not the most straightforward way to store and manipulate data in Python. A format that's more popular with data scientist is to use the `pandas` library to create a `DataFrame`. This library has a lot of functionality that makes it easy to run the common tasks data scientists do with data.
#
# 4. Read the data from the above query into a `DataFrame` and call it `books_df`. HINT: Use `pd.DataFrame` and specify the names to use for the columns.

# %%
import pandas as pd

books_df = pd.DataFrame(data = books_table, columns = ['title','author_1','author_2','num_authors','ISBN','has_data','desc_len','year_published'])
books_df
# Out:
#                                title  \
# 0                  Unlocking Android
# 1                   Flex 4 in Action
# 2                   iBATIS in Action
# 3   Spring Dynamic Modules in Action
# 4        Portlets and Apache Portals
# 5                   Struts in Action
# 6                   Groovy in Action
# 7   Groovy in Action, Second Edition
# 8              Tuscany SCA in Action
# 9                     LINQ in Action
# 10      Entity Framework 4 in Action
# 11         SQL Server MVP Deep Dives
# 12         SQL Server MVP Deep Dives
# 13           ASP.NET MVC 2 in Action
# 14           ASP.NET MVC 4 in Action
# 15                 Node.js in Action
#
#                                              author_1                author_2  \
# 0                                    W. Frank Ableson         Charlie Collins
# 1                                         Tariq Ahmed             Dan Orlando
# 2                                       Clinton Begin          Brandon Goodin
# 3                                  Arnaud Cogoluegnes        Thierry Templier
# 4                                       Stefan Hepper           Peter Fischer
# 5                                       Ted N. Husted         Cedric Dumoulin
# 6                     Dierk Koenig with Andrew Glover               Paul King
# 7                                         Dierk König       Guillaume Laforge
# 8                                          Simon Laws         Mark Combellack
# 9                                   Fabrice Marguerie           Steve Eichert
# 10                                   Stefano Mostarda        Marco De Sanctis
# 11              Contributions from 53 SQL Server MVPs  Edited by Paul Nielsen
# 12  Contributions from 53 SQL Server MVPs; Edited ...           Kalen Delaney
# 13                                    Jeffrey Palermo           Ben Scheirman
# 14                                    Jeffrey Palermo            Jimmy Bogard
# 15                                      Mike Cantelon             Marc Harter
#
#     num_authors           ISBN has_data  desc_len  year_published
# 0             3     1933988673     True       252          2009.0
# 1             4     1935182420     True       329          2010.0
# 2             3     1932394826     True       159          2007.0
# 3             4     1935182307     True       183          2010.0
# 4             5           None     True       153          2005.0
# 5             4     1932394249     True       137          2002.0
# 6             4     1932394842     True       235          2007.0
# 7             8     1935182447     True       289             NaN
# 8             5     1933988894     True       245          2011.0
# 9             3     1933988169     True       329          2008.0
# 10            4     1935182188     True       178          2011.0
# 11            8     1935182048     True       163          2009.0
# 12            7  9781935182047     True       100          2009.0
# 13            6     193518279X     True       291          2010.0
# 14            6     1617290416     True       277          2012.0
# 15            5     1617290572     True       292          2013.0

# %% [markdown]
# 5. Display the first few columns of a `DataFrame` by calling its `head` method.

# %%
books_df[books_df.columns[0:2]].head()
# Out:
#                               title            author_1
# 0                 Unlocking Android    W. Frank Ableson
# 1                  Flex 4 in Action         Tariq Ahmed
# 2                  iBATIS in Action       Clinton Begin
# 3  Spring Dynamic Modules in Action  Arnaud Cogoluegnes
# 4       Portlets and Apache Portals       Stefan Hepper

# %% [markdown]
# Another way of saying it is that a `DataFrame` is an **abstraction** on top of `numpy` arrays: i.e. a `DataFrame` is a more **high-level** object than a `numpy` array.
#
# 6. Call the `values` attribute of your `DataFrame` to convert it into a numpy array and display the first 3 elements of the array.

# %%
np_array_books_df = books_df.values
np_array_books_df[0:3]
# Out:
# array([['Unlocking Android', 'W. Frank Ableson', 'Charlie Collins', 3,
#         '1933988673', 'True', 252, 2009.0],
#        ['Flex 4 in Action', 'Tariq Ahmed', 'Dan Orlando', 4,
#         '1935182420', 'True', 329, 2010.0],
#        ['iBATIS in Action', 'Clinton Begin', 'Brandon Goodin', 3,
#         '1932394826', 'True', 159, 2007.0]], dtype=object)

# %% [markdown]
# Now we can judge which object is more "user-friendly". That's one of the things that abstractions allow us to do: build more user-friendly (abstract) objects from less user-friendly (but more fundamental) objects.
